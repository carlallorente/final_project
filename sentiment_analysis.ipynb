# %%
#Importing libraries 
import tweepy
import re #To provide regular expression support.
import pandas as pd
from textblob import TextBlob # A library for processing textual data

#Defining the credentials
API_KEY = "QY6a4RckRfDgKDezclFr9IBcc"
API_SECRET = "BORwcgpPpoenadRDQUqmvTozutGZgvlc6BvlA1fzr9Fq4TuTnO"
ACCESS_TOKEN = "1550691355-VPMmM9DMahNNkeolwnaPWfMICjfnquJaznABozm"
ACCESS_SECRET = "3qgaQrWUzV4TdQiTf6DB2OXSfW4VAXTW5YUT5SEOWGDjN"
twitter_auth=tweepy.OAuthHandler(API_KEY, API_SECRET)
api=tweepy.API(twitter_auth)

#To find Netflix word
t=api.search("Netflix", count=100)

#Creating a chart with different features (using pd.DataFrame function)
netflixchart = pd.DataFrame(columns=('TWEET', 'SENTIMENT', 'SUBJECTIVITY',
                          'NUMBER_OF_RTS'))

#To get rid of duplicates
netflixchart.sort_values("TWEET", inplace = True)
netflixchart.drop_duplicates(subset ="tweet_text", keep = False, inplace = True)

#Apply TextBlob
for tweet in t:
  if tweet.lang == "en":
    sentimentText = TextBlob(tweet.text)
    netflixchart = netflixchart.append({'TWEET': re.sub(r'http\S+', '', tweet.text),
                    'SENTIMENT': sentimentText.sentiment.polarity,
                    'SUBJECTIVITY': sentimentText.sentiment.subjectivity,
                    'NUMBER_OF_RTS': tweet.retweet_count,},
                   ignore_index=True)

netflixchart.head(15)
# Out:
#                                                 TWEET  SENTIMENT  \
# 0   RT @disclosetv: JUST IN - Netflix stock crashe...   0.000000
# 1   RT @GeorgePapa19: With Netflix shares down 25%...   0.007407
# 2   RT @HishamSidnaaz17: Please do watch the new v...   0.136364
# 3   RT @notthreadguy: Netflix didn’t even dump lik...   0.000000
# 4   RT @32gipad: Elon Musk rips Netflix for 'woke ...   0.000000
# 5   RT @disclosetv: JUST IN - Netflix stock crashe...   0.000000
# 6   @najaemzgurl hi! @orelkies ada app premium nih...   0.000000
# 7   RT @the_blueprint: old netflix that had everyt...   0.209091
# 8   @zerohedge Netflix pulling a Facebook from bac...   0.000000
# 9   WHY DOES NETFLIX KEEP RUINING THEIR BUSINESS L...   0.000000
# 10  RT @scottygb: Netflix’s decline in subscribers...   0.250000
# 11  RT @GRALCreates: Poor Netflix has now crashed ...   0.125000
# 12  RT @disclosetv: JUST IN - Netflix stock crashe...   0.000000
# 13  RT @scottygb: Netflix’s decline in subscribers...   0.250000
# 14  @nobullshytrader What about netflix, yig think...   0.000000
#
#     SUBJECTIVITY NUMBER_OF_RTS
# 0       0.500000           332
# 1       0.359259          1123
# 2       0.454545            35
# 3       0.000000            34
# 4       0.000000             4
# 5       0.500000           332
# 6       0.000000             0
# 7       0.213636            31
# 8       0.000000             0
# 9       0.000000             0
# 10      0.553571           332
# 11      0.597222             1
# 12      0.500000           332
# 13      0.553571           332
# 14      0.000000             0
